# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

start_time = pd.datetime.now()

# %%
mydata = pd.read_csv('NY property data.csv')

# %%
mydata.shape
# Out:
# (1070994, 32)

# %%
numrecords = len(mydata)
print(numrecords)
# Out:
# 1070994

# %%
import pandas_profiling
profile = pandas_profiling.ProfileReport(mydata)
profile.to_file('DQR.html')

# %%
mydata.dtypes
# Out:
# RECORD        int64
# BBLE         object
# B             int64
# BLOCK         int64
# LOT           int64
# EASEMENT     object
# OWNER        object
# BLDGCL       object
# TAXCLASS     object
# LTFRONT       int64
# LTDEPTH       int64
# EXT          object
# STORIES     float64
# FULLVAL     float64
# AVLAND      float64
# AVTOT       float64
# EXLAND      float64
# EXTOT       float64
# EXCD1       float64
# STADDR       object
# ZIP         float64
# EXMPTCL      object
# BLDFRONT      int64
# BLDDEPTH      int64
# AVLAND2     float64
# AVTOT2      float64
# EXLAND2     float64
# EXTOT2      float64
# EXCD2       float64
# PERIOD       object
# YEAR         object
# VALTYPE      object
# dtype: object

# %%
mydata.head(10).transpose()
# Out:
#                               0                      1                      2  \
# RECORD                        1                      2                      3
# BBLE                 1000010101             1000010201             1000020001
# B                             1                      1                      1
# BLOCK                         1                      1                      2
# LOT                         101                    201                      1
# EASEMENT                    NaN                    NaN                    NaN
# OWNER     U S GOVT LAND & BLDGS  U S GOVT LAND & BLDGS  DEPT OF GENERAL SERVI
# BLDGCL                       P7                     Z9                     Y7
# TAXCLASS                      4                      4                      4
# LTFRONT                     500                     27                    709
# LTDEPTH                    1046                      0                    564
# EXT                         NaN                    NaN                      E
# STORIES                     NaN                    NaN                      3
# FULLVAL                2.14e+07              1.938e+08            1.04686e+08
# AVLAND               4.2255e+06              1.431e+07            3.90087e+07
# AVTOT                  9.63e+06              8.721e+07            4.71087e+07
# EXLAND               4.2255e+06              1.431e+07            3.90087e+07
# EXTOT                  9.63e+06              8.721e+07            4.71087e+07
# EXCD1                      4600                   4600                   2191
# STADDR         1 LIBERTY ISLAND         1 ELLIS ISLAND        MARGINAL STREET
# ZIP                       10004                  10004                  10004
# EXMPTCL                      X3                     X3                     X1
# BLDFRONT                      0                      0                    709
# BLDDEPTH                      0                      0                    564
# AVLAND2              3.7755e+06            1.11114e+07            3.23218e+07
# AVTOT2                8.613e+06            8.06904e+07            4.01795e+07
# EXLAND2              3.7755e+06            1.11114e+07            3.23218e+07
# EXTOT2                8.613e+06            8.06904e+07            4.01795e+07
# EXCD2                       NaN                    NaN                    NaN
# PERIOD                    FINAL                  FINAL                  FINAL
# YEAR                    2010/11                2010/11                2010/11
# VALTYPE                   AC-TR                  AC-TR                  AC-TR
#
#                               3                     4                     5  \
# RECORD                        4                     5                     6
# BBLE                 1000020023            1000030001            1000030002
# B                             1                     1                     1
# BLOCK                         2                     3                     3
# LOT                          23                     1                     2
# EASEMENT                    NaN                   NaN                   NaN
# OWNER     DEPARTMENT OF BUSINES  PARKS AND RECREATION  PARKS AND RECREATION
# BLDGCL                       T2                    Q1                    Q1
# TAXCLASS                      4                     4                     4
# LTFRONT                     793                   323                   496
# LTDEPTH                     551                  1260                    76
# EXT                         NaN                   NaN                   NaN
# STORIES                       2                     1                   NaN
# FULLVAL                3.92e+07             2.723e+08              1.06e+07
# AVLAND               1.5255e+07            1.2105e+08              4.77e+06
# AVTOT                 1.764e+07           1.22535e+08              4.77e+06
# EXLAND               1.5255e+07            1.2105e+08              4.77e+06
# EXTOT                 1.764e+07           1.22535e+08              4.77e+06
# EXCD1                      2191                  2231                  2231
# STADDR                   PIER 6          BATTERY PARK    PETER MINUIT PLAZA
# ZIP                       10004                 10004                 10004
# EXMPTCL                      X1                    X1                    X1
# BLDFRONT                     85                    89                     0
# BLDDEPTH                    551                    57                     0
# AVLAND2              1.3644e+07           1.06349e+08            4.2687e+06
# AVTOT2                1.575e+07           1.07758e+08            4.2687e+06
# EXLAND2              1.3644e+07           1.06349e+08            4.2687e+06
# EXTOT2                1.575e+07           1.07758e+08            4.2687e+06
# EXCD2                       NaN                   NaN                   NaN
# PERIOD                    FINAL                 FINAL                 FINAL
# YEAR                    2010/11               2010/11               2010/11
# VALTYPE                   AC-TR                 AC-TR                 AC-TR
#
#                              6                   7                  8  \
# RECORD                       7                   8                  9
# BBLE                1000030003          1000030010         1000041001
# B                            1                   1                  1
# BLOCK                        3                   3                  4
# LOT                          3                  10               1001
# EASEMENT                   NaN                 NaN                NaN
# OWNER     PARKS AND RECREATION  DEPT RE-CITY OF NY  TRZ HOLDINGS, LLC
# BLDGCL                      Q1                  Z9                 R5
# TAXCLASS                     4                   4                  4
# LTFRONT                    180                 362                  0
# LTDEPTH                    370                 177                  0
# EXT                        NaN                 NaN                NaN
# STORIES                      1                   3                 50
# FULLVAL               8.49e+06            2.81e+07        3.94476e+06
# AVLAND              3.8205e+06           1.107e+07             636093
# AVTOT               3.8205e+06          1.2645e+07        1.77514e+06
# EXLAND              3.8205e+06           1.107e+07                  0
# EXTOT               3.8205e+06          1.2645e+07                  0
# EXCD1                     2231                4600                NaN
# STADDR      PETER MINUIT PLAZA      1 SOUTH STREET     1 WATER STREET
# ZIP                      10004               10004              10004
# EXMPTCL                     X1                  X3                NaN
# BLDFRONT                    16                  37                  0
# BLDDEPTH                    19                 227                  0
# AVLAND2             3.5469e+06           9.882e+06             636093
# AVTOT2              3.5469e+06          1.1304e+07        2.04929e+06
# EXLAND2             3.5469e+06           9.882e+06                NaN
# EXTOT2              3.5469e+06          1.1304e+07                NaN
# EXCD2                      NaN                 NaN                NaN
# PERIOD                   FINAL               FINAL              FINAL
# YEAR                   2010/11             2010/11            2010/11
# VALTYPE                  AC-TR               AC-TR              AC-TR
#
#                           9
# RECORD                   10
# BBLE             1000041002
# B                         1
# BLOCK                     4
# LOT                    1002
# EASEMENT                NaN
# OWNER     TRZ HOLDINGS, LLC
# BLDGCL                   R5
# TAXCLASS                  4
# LTFRONT                   0
# LTDEPTH                   0
# EXT                     NaN
# STORIES                  50
# FULLVAL         5.70093e+06
# AVLAND               919276
# AVTOT           2.56542e+06
# EXLAND                    0
# EXTOT                     0
# EXCD1                   NaN
# STADDR       1 WATER STREET
# ZIP                   10004
# EXMPTCL                 NaN
# BLDFRONT                  0
# BLDDEPTH                  0
# AVLAND2              919276
# AVTOT2          2.96162e+06
# EXLAND2                 NaN
# EXTOT2                  NaN
# EXCD2                   NaN
# PERIOD                FINAL
# YEAR                2010/11
# VALTYPE               AC-TR

# %%
mydata.tail().transpose()
# Out:
#                      1070989             1070990             1070991  \
# RECORD               1070990             1070991             1070992
# BBLE              5080500083          5080500086          5080500089
# B                          5                   5                   5
# BLOCK                   8050                8050                8050
# LOT                       83                  86                  89
# EASEMENT                 NaN                 NaN                 NaN
# OWNER            TOBIN, GALE    SHERRI MILINAZZO        JOHN GERVASI
# BLDGCL                    A1                  A1                  A1
# TAXCLASS                   1                   1                   1
# LTFRONT                   60                  62                  53
# LTDEPTH                  120                 228                 273
# EXT                      NaN                 NaN                   G
# STORIES                  2.5                 2.5                   2
# FULLVAL               438000              544000              480000
# AVLAND                 14536                9303               14790
# AVTOT                  23322               14929               22975
# EXLAND                  1620                1620               14728
# EXTOT                   1620                1620               14728
# EXCD1                   1017                1017                1015
# STADDR    142 BENTLEY STREET  146 BENTLEY STREET  150 BENTLEY STREET
# ZIP                    10307               10307               10307
# EXMPTCL                  NaN                 NaN                 NaN
# BLDFRONT                  30                  32                  24
# BLDDEPTH                  26                  26                  32
# AVLAND2                  NaN                 NaN                 NaN
# AVTOT2                   NaN                 NaN                 NaN
# EXLAND2                  NaN                 NaN                 NaN
# EXTOT2                   NaN                 NaN                 NaN
# EXCD2                    NaN                 NaN                1017
# PERIOD                 FINAL               FINAL               FINAL
# YEAR                 2010/11             2010/11             2010/11
# VALTYPE                AC-TR               AC-TR               AC-TR
#
#                      1070992             1070993
# RECORD               1070993             1070994
# BBLE              5080500092          5080500094
# B                          5                   5
# BLOCK                   8050                8050
# LOT                       92                  94
# EASEMENT                 NaN                 NaN
# OWNER            RITA M MOOG      EDWARD DONOHUE
# BLDGCL                    A1                  A1
# TAXCLASS                   1                   1
# LTFRONT                   52                  50
# LTDEPTH                  136                  80
# EXT                      NaN                 NaN
# STORIES                    2                   2
# FULLVAL               543000              473000
# AVLAND                 12388               14061
# AVTOT                  23037               22394
# EXLAND                  1620                1620
# EXTOT                   1620                1620
# EXCD1                   1017                1017
# STADDR    156 BENTLEY STREET  162 BENTLEY STREET
# ZIP                    10307               10307
# EXMPTCL                  NaN                 NaN
# BLDFRONT                  32                  30
# BLDDEPTH                  21                  24
# AVLAND2                  NaN                 NaN
# AVTOT2                   NaN                 NaN
# EXLAND2                  NaN                 NaN
# EXTOT2                   NaN                 NaN
# EXCD2                    NaN                 NaN
# PERIOD                 FINAL               FINAL
# YEAR                 2010/11             2010/11
# VALTYPE                AC-TR               AC-TR

# %%
mydata.describe().transpose()
# Out:
#               count           mean           std      min        25%  \
# RECORD    1070994.0  535497.500000  3.091695e+05      1.0  267749.25
# B         1070994.0       3.215427  1.201197e+00      1.0       3.00
# BLOCK     1070994.0    4757.239213  3.676579e+03      1.0    1555.00
# LOT       1070994.0     364.722117  8.532152e+02      1.0      23.00
# LTFRONT   1070994.0      36.635301  7.403284e+01      0.0      19.00
# LTDEPTH   1070994.0      88.861594  7.639628e+01      0.0      80.00
# STORIES   1014730.0       5.006918  8.365707e+00      1.0       2.00
# FULLVAL   1070994.0  874264.505434  1.158243e+07      0.0  304000.00
# AVLAND    1070994.0   85067.918672  4.057260e+06      0.0    9180.00
# AVTOT     1070994.0  227238.168711  6.877529e+06      0.0   18374.00
# EXLAND    1070994.0   36423.890692  3.981576e+06      0.0       0.00
# EXTOT     1070994.0   91186.981682  6.508403e+06      0.0       0.00
# EXCD1      638488.0    1602.014232  1.384227e+03   1010.0    1017.00
# ZIP       1041104.0   10923.963366  5.284208e+02  10001.0   10314.00
# BLDFRONT  1070994.0      23.042770  3.557970e+01      0.0      15.00
# BLDDEPTH  1070994.0      39.922836  4.270715e+01      0.0      26.00
# AVLAND2    282726.0  246235.719265  6.178963e+06      3.0    5705.00
# AVTOT2     282732.0  713911.436173  1.165253e+07      3.0   33912.00
# EXLAND2     87449.0  351235.684273  1.080221e+07      1.0    2090.00
# EXTOT2     130828.0  656768.281904  1.607251e+07      7.0    2870.00
# EXCD2       92948.0    1364.041679  1.094706e+03   1011.0    1017.00
#
#                50%        75%           max
# RECORD    535497.5  803245.75  1.070994e+06
# B              3.0       4.00  5.000000e+00
# BLOCK       4047.0    6898.00  1.635000e+04
# LOT           49.0     143.00  9.978000e+03
# LTFRONT       25.0      40.00  9.999000e+03
# LTDEPTH      100.0     100.00  9.999000e+03
# STORIES        2.0       3.00  1.190000e+02
# FULLVAL   447000.0  619000.00  6.150000e+09
# AVLAND     13678.0   19740.00  2.668500e+09
# AVTOT      25340.0   45438.00  4.668309e+09
# EXLAND      1620.0    1620.00  2.668500e+09
# EXTOT       1620.0    2090.00  4.668309e+09
# EXCD1       1017.0    1017.00  7.170000e+03
# ZIP        11214.0   11364.00  3.380300e+04
# BLDFRONT      20.0      24.00  7.575000e+03
# BLDDEPTH      39.0      50.00  9.393000e+03
# AVLAND2    20145.0   62640.00  2.371005e+09
# AVTOT2     79962.5  240551.00  4.501180e+09
# EXLAND2     3048.0   31779.00  2.371005e+09
# EXTOT2     37062.0  106840.75  4.501180e+09
# EXCD2       1017.0    1017.00  7.160000e+03

# %%
mydata.count()
# Out:
# RECORD      1070994
# BBLE        1070994
# B           1070994
# BLOCK       1070994
# LOT         1070994
# EASEMENT       4636
# OWNER       1039249
# BLDGCL      1070994
# TAXCLASS    1070994
# LTFRONT     1070994
# LTDEPTH     1070994
# EXT          354305
# STORIES     1014730
# FULLVAL     1070994
# AVLAND      1070994
# AVTOT       1070994
# EXLAND      1070994
# EXTOT       1070994
# EXCD1        638488
# STADDR      1070318
# ZIP         1041104
# EXMPTCL       15579
# BLDFRONT    1070994
# BLDDEPTH    1070994
# AVLAND2      282726
# AVTOT2       282732
# EXLAND2       87449
# EXTOT2       130828
# EXCD2         92948
# PERIOD      1070994
# YEAR        1070994
# VALTYPE     1070994
# dtype: int64

# %%
summary = mydata.describe().transpose()
summary
# Out:
#               count           mean           std      min        25%  \
# RECORD    1070994.0  535497.500000  3.091695e+05      1.0  267749.25
# B         1070994.0       3.215427  1.201197e+00      1.0       3.00
# BLOCK     1070994.0    4757.239213  3.676579e+03      1.0    1555.00
# LOT       1070994.0     364.722117  8.532152e+02      1.0      23.00
# LTFRONT   1070994.0      36.635301  7.403284e+01      0.0      19.00
# LTDEPTH   1070994.0      88.861594  7.639628e+01      0.0      80.00
# STORIES   1014730.0       5.006918  8.365707e+00      1.0       2.00
# FULLVAL   1070994.0  874264.505434  1.158243e+07      0.0  304000.00
# AVLAND    1070994.0   85067.918672  4.057260e+06      0.0    9180.00
# AVTOT     1070994.0  227238.168711  6.877529e+06      0.0   18374.00
# EXLAND    1070994.0   36423.890692  3.981576e+06      0.0       0.00
# EXTOT     1070994.0   91186.981682  6.508403e+06      0.0       0.00
# EXCD1      638488.0    1602.014232  1.384227e+03   1010.0    1017.00
# ZIP       1041104.0   10923.963366  5.284208e+02  10001.0   10314.00
# BLDFRONT  1070994.0      23.042770  3.557970e+01      0.0      15.00
# BLDDEPTH  1070994.0      39.922836  4.270715e+01      0.0      26.00
# AVLAND2    282726.0  246235.719265  6.178963e+06      3.0    5705.00
# AVTOT2     282732.0  713911.436173  1.165253e+07      3.0   33912.00
# EXLAND2     87449.0  351235.684273  1.080221e+07      1.0    2090.00
# EXTOT2     130828.0  656768.281904  1.607251e+07      7.0    2870.00
# EXCD2       92948.0    1364.041679  1.094706e+03   1011.0    1017.00
#
#                50%        75%           max
# RECORD    535497.5  803245.75  1.070994e+06
# B              3.0       4.00  5.000000e+00
# BLOCK       4047.0    6898.00  1.635000e+04
# LOT           49.0     143.00  9.978000e+03
# LTFRONT       25.0      40.00  9.999000e+03
# LTDEPTH      100.0     100.00  9.999000e+03
# STORIES        2.0       3.00  1.190000e+02
# FULLVAL   447000.0  619000.00  6.150000e+09
# AVLAND     13678.0   19740.00  2.668500e+09
# AVTOT      25340.0   45438.00  4.668309e+09
# EXLAND      1620.0    1620.00  2.668500e+09
# EXTOT       1620.0    2090.00  4.668309e+09
# EXCD1       1017.0    1017.00  7.170000e+03
# ZIP        11214.0   11364.00  3.380300e+04
# BLDFRONT      20.0      24.00  7.575000e+03
# BLDDEPTH      39.0      50.00  9.393000e+03
# AVLAND2    20145.0   62640.00  2.371005e+09
# AVTOT2     79962.5  240551.00  4.501180e+09
# EXLAND2     3048.0   31779.00  2.371005e+09
# EXTOT2     37062.0  106840.75  4.501180e+09
# EXCD2       1017.0    1017.00  7.160000e+03

# %%
summary.to_excel('/Users/jam/Downloads/Analytics/DSO562/HW1/summary.xlsx')

# %%
column = mydata.columns
for i in column:
    unique = mydata[i].unique()
    count = len(unique)
    summary.loc[i,'unique_val'] = count
    
summary
# Out:
#               count           mean           std      min        25%  \
# RECORD    1070994.0  535497.500000  3.091695e+05      1.0  267749.25
# B         1070994.0       3.215427  1.201197e+00      1.0       3.00
# BLOCK     1070994.0    4757.239213  3.676579e+03      1.0    1555.00
# LOT       1070994.0     364.722117  8.532152e+02      1.0      23.00
# LTFRONT   1070994.0      36.635301  7.403284e+01      0.0      19.00
# LTDEPTH   1070994.0      88.861594  7.639628e+01      0.0      80.00
# STORIES   1014730.0       5.006918  8.365707e+00      1.0       2.00
# FULLVAL   1070994.0  874264.505434  1.158243e+07      0.0  304000.00
# AVLAND    1070994.0   85067.918672  4.057260e+06      0.0    9180.00
# AVTOT     1070994.0  227238.168711  6.877529e+06      0.0   18374.00
# EXLAND    1070994.0   36423.890692  3.981576e+06      0.0       0.00
# EXTOT     1070994.0   91186.981682  6.508403e+06      0.0       0.00
# EXCD1      638488.0    1602.014232  1.384227e+03   1010.0    1017.00
# ZIP       1041104.0   10923.963366  5.284208e+02  10001.0   10314.00
# BLDFRONT  1070994.0      23.042770  3.557970e+01      0.0      15.00
# BLDDEPTH  1070994.0      39.922836  4.270715e+01      0.0      26.00
# AVLAND2    282726.0  246235.719265  6.178963e+06      3.0    5705.00
# AVTOT2     282732.0  713911.436173  1.165253e+07      3.0   33912.00
# EXLAND2     87449.0  351235.684273  1.080221e+07      1.0    2090.00
# EXTOT2     130828.0  656768.281904  1.607251e+07      7.0    2870.00
# EXCD2       92948.0    1364.041679  1.094706e+03   1011.0    1017.00
# BBLE            NaN            NaN           NaN      NaN        NaN
# EASEMENT        NaN            NaN           NaN      NaN        NaN
# OWNER           NaN            NaN           NaN      NaN        NaN
# BLDGCL          NaN            NaN           NaN      NaN        NaN
# TAXCLASS        NaN            NaN           NaN      NaN        NaN
# EXT             NaN            NaN           NaN      NaN        NaN
# STADDR          NaN            NaN           NaN      NaN        NaN
# EXMPTCL         NaN            NaN           NaN      NaN        NaN
# PERIOD          NaN            NaN           NaN      NaN        NaN
# YEAR            NaN            NaN           NaN      NaN        NaN
# VALTYPE         NaN            NaN           NaN      NaN        NaN
#
#                50%        75%           max  unique_val
# RECORD    535497.5  803245.75  1.070994e+06   1070994.0
# B              3.0       4.00  5.000000e+00         5.0
# BLOCK       4047.0    6898.00  1.635000e+04     13984.0
# LOT           49.0     143.00  9.978000e+03      6366.0
# LTFRONT       25.0      40.00  9.999000e+03      1297.0
# LTDEPTH      100.0     100.00  9.999000e+03      1370.0
# STORIES        2.0       3.00  1.190000e+02       112.0
# FULLVAL   447000.0  619000.00  6.150000e+09    109324.0
# AVLAND     13678.0   19740.00  2.668500e+09     70921.0
# AVTOT      25340.0   45438.00  4.668309e+09    112914.0
# EXLAND      1620.0    1620.00  2.668500e+09     33419.0
# EXTOT       1620.0    2090.00  4.668309e+09     64255.0
# EXCD1       1017.0    1017.00  7.170000e+03       130.0
# ZIP        11214.0   11364.00  3.380300e+04       197.0
# BLDFRONT      20.0      24.00  7.575000e+03       612.0
# BLDDEPTH      39.0      50.00  9.393000e+03       621.0
# AVLAND2    20145.0   62640.00  2.371005e+09     58592.0
# AVTOT2     79962.5  240551.00  4.501180e+09    111361.0
# EXLAND2     3048.0   31779.00  2.371005e+09     22196.0
# EXTOT2     37062.0  106840.75  4.501180e+09     48349.0
# EXCD2       1017.0    1017.00  7.160000e+03        61.0
# BBLE           NaN        NaN           NaN   1070994.0
# EASEMENT       NaN        NaN           NaN        13.0
# OWNER          NaN        NaN           NaN    863347.0
# BLDGCL         NaN        NaN           NaN       200.0
# TAXCLASS       NaN        NaN           NaN        11.0
# EXT            NaN        NaN           NaN         4.0
# STADDR         NaN        NaN           NaN    839281.0
# EXMPTCL        NaN        NaN           NaN        15.0
# PERIOD         NaN        NaN           NaN         1.0
# YEAR           NaN        NaN           NaN         1.0
# VALTYPE        NaN        NaN           NaN         1.0

# %%
column = mydata.columns
for i in column:
    zero = mydata[mydata[i] == 0]
    count = len(zero)
    summary.loc[i,'zero'] = count
    
summary
# Out:
#               count           mean           std      min        25%  \
# RECORD    1070994.0  535497.500000  3.091695e+05      1.0  267749.25
# B         1070994.0       3.215427  1.201197e+00      1.0       3.00
# BLOCK     1070994.0    4757.239213  3.676579e+03      1.0    1555.00
# LOT       1070994.0     364.722117  8.532152e+02      1.0      23.00
# LTFRONT   1070994.0      36.635301  7.403284e+01      0.0      19.00
# LTDEPTH   1070994.0      88.861594  7.639628e+01      0.0      80.00
# STORIES   1014730.0       5.006918  8.365707e+00      1.0       2.00
# FULLVAL   1070994.0  874264.505434  1.158243e+07      0.0  304000.00
# AVLAND    1070994.0   85067.918672  4.057260e+06      0.0    9180.00
# AVTOT     1070994.0  227238.168711  6.877529e+06      0.0   18374.00
# EXLAND    1070994.0   36423.890692  3.981576e+06      0.0       0.00
# EXTOT     1070994.0   91186.981682  6.508403e+06      0.0       0.00
# EXCD1      638488.0    1602.014232  1.384227e+03   1010.0    1017.00
# ZIP       1041104.0   10923.963366  5.284208e+02  10001.0   10314.00
# BLDFRONT  1070994.0      23.042770  3.557970e+01      0.0      15.00
# BLDDEPTH  1070994.0      39.922836  4.270715e+01      0.0      26.00
# AVLAND2    282726.0  246235.719265  6.178963e+06      3.0    5705.00
# AVTOT2     282732.0  713911.436173  1.165253e+07      3.0   33912.00
# EXLAND2     87449.0  351235.684273  1.080221e+07      1.0    2090.00
# EXTOT2     130828.0  656768.281904  1.607251e+07      7.0    2870.00
# EXCD2       92948.0    1364.041679  1.094706e+03   1011.0    1017.00
# BBLE            NaN            NaN           NaN      NaN        NaN
# EASEMENT        NaN            NaN           NaN      NaN        NaN
# OWNER           NaN            NaN           NaN      NaN        NaN
# BLDGCL          NaN            NaN           NaN      NaN        NaN
# TAXCLASS        NaN            NaN           NaN      NaN        NaN
# EXT             NaN            NaN           NaN      NaN        NaN
# STADDR          NaN            NaN           NaN      NaN        NaN
# EXMPTCL         NaN            NaN           NaN      NaN        NaN
# PERIOD          NaN            NaN           NaN      NaN        NaN
# YEAR            NaN            NaN           NaN      NaN        NaN
# VALTYPE         NaN            NaN           NaN      NaN        NaN
#
#                50%        75%           max  unique_val      zero
# RECORD    535497.5  803245.75  1.070994e+06   1070994.0       0.0
# B              3.0       4.00  5.000000e+00         5.0       0.0
# BLOCK       4047.0    6898.00  1.635000e+04     13984.0       0.0
# LOT           49.0     143.00  9.978000e+03      6366.0       0.0
# LTFRONT       25.0      40.00  9.999000e+03      1297.0  169108.0
# LTDEPTH      100.0     100.00  9.999000e+03      1370.0  170128.0
# STORIES        2.0       3.00  1.190000e+02       112.0       0.0
# FULLVAL   447000.0  619000.00  6.150000e+09    109324.0   13007.0
# AVLAND     13678.0   19740.00  2.668500e+09     70921.0   13009.0
# AVTOT      25340.0   45438.00  4.668309e+09    112914.0   13007.0
# EXLAND      1620.0    1620.00  2.668500e+09     33419.0  491699.0
# EXTOT       1620.0    2090.00  4.668309e+09     64255.0  432572.0
# EXCD1       1017.0    1017.00  7.170000e+03       130.0       0.0
# ZIP        11214.0   11364.00  3.380300e+04       197.0       0.0
# BLDFRONT      20.0      24.00  7.575000e+03       612.0  228815.0
# BLDDEPTH      39.0      50.00  9.393000e+03       621.0  228853.0
# AVLAND2    20145.0   62640.00  2.371005e+09     58592.0       0.0
# AVTOT2     79962.5  240551.00  4.501180e+09    111361.0       0.0
# EXLAND2     3048.0   31779.00  2.371005e+09     22196.0       0.0
# EXTOT2     37062.0  106840.75  4.501180e+09     48349.0       0.0
# EXCD2       1017.0    1017.00  7.160000e+03        61.0       0.0
# BBLE           NaN        NaN           NaN   1070994.0       0.0
# EASEMENT       NaN        NaN           NaN        13.0       0.0
# OWNER          NaN        NaN           NaN    863347.0       0.0
# BLDGCL         NaN        NaN           NaN       200.0       0.0
# TAXCLASS       NaN        NaN           NaN        11.0       0.0
# EXT            NaN        NaN           NaN         4.0       0.0
# STADDR         NaN        NaN           NaN    839281.0       0.0
# EXMPTCL        NaN        NaN           NaN        15.0       0.0
# PERIOD         NaN        NaN           NaN         1.0       0.0
# YEAR           NaN        NaN           NaN         1.0       0.0
# VALTYPE        NaN        NaN           NaN         1.0       0.0

# %%
mydata['RECORD'].unique()
# Out:
# array([      1,       2,       3, ..., 1070992, 1070993, 1070994])

# %%
len(mydata['RECORD'])
# Out:
# 1070994

# %%
# mydata.set_index('RECORD', inplace = True)

# %%
len(mydata['BBLE'].unique())
# Out:
# 1070994

# %%
mydata['BBLE'].head()
# Out:
# 0    1000010101
# 1    1000010201
# 2    1000020001
# 3    1000020023
# 4    1000030001
# Name: BBLE, dtype: object

# %%
len(mydata['B'].unique())
# Out:
# 5

# %%
mydata['PERIOD'].value_counts()
# Out:
# FINAL    1070994
# Name: PERIOD, dtype: int64

# %%
mydata['BLDGCL'].count() * 100 / numrecords
# Out:
# 100.0

# %%
mydata['EXCD2'].count() * 100 / numrecords
# Out:
# 8.678666733893934

# %%
len(mydata['BLOCK'].unique())
# Out:
# 13984

# %%
mydata['BLOCK'].value_counts()
# Out:
# 3944     3888
# 16       3786
# 3943     3424
# 3938     2794
# 1171     2535
#          ...
# 15880       1
# 15895       1
# 15892       1
# 10119       1
# 9067        1
# Name: BLOCK, Length: 13984, dtype: int64

# %%
mydata['BLOCK'].min()
# Out:
# 1

# %%
mydata['LOT'].count() * 100 / numrecords
# Out:
# 100.0

# %%
len(mydata['LOT'].unique())
# Out:
# 6366

# %%
mydata['LOT'].value_counts()
# Out:
# 1       24367
# 20      12294
# 15      12171
# 12      12143
# 14      12074
#         ...
# 5547        1
# 8075        1
# 6883        1
# 5460        1
# 9108        1
# Name: LOT, Length: 6366, dtype: int64

# %%
mydata['LOT'].min()
# Out:
# 1

# %%
mydata['EASEMENT'].count() * 100 / numrecords
# Out:
# 0.4328689049611856

# %%
len(mydata['EASEMENT'].unique())
# Out:
# 13

# %%
mydata['EASEMENT'].value_counts()
# Out:
# E    4148
# F     296
# G     102
# H      33
# N      19
# I      16
# J       8
# K       5
# L       3
# P       3
# M       2
# U       1
# Name: EASEMENT, dtype: int64

# %%
plt.rcParams["figure.figsize"] = [15,8]
sns.set(font_scale=2)
plot = sns.countplot(x='EASEMENT', data = mydata, order = mydata['EASEMENT'].value_counts().index)
plot.set_yscale('log')
plt.savefig('hist.png')

# %%
mydata['B'].value_counts()
# Out:
# 4    358046
# 3    323243
# 1    146220
# 5    136200
# 2    107285
# Name: B, dtype: int64

# %%
plt.rcParams["figure.figsize"] = [15,8]
plot = sns.countplot(x='B', data = mydata, order = mydata['B'].value_counts().index)
plt.savefig('2.png',bbox_inches='tight')
plt.show()

# %%
plt.rcParams["figure.figsize"] = [15,8]
mydata['BLOCK'].value_counts().head(15).plot(kind = 'bar')
plt.xlabel('BLOCK')
plt.ylabel('count')
plt.savefig('1.png',bbox_inches='tight')
plt.show()

# %%
plt.rcParams["figure.figsize"] = [15,8]
mydata['LOT'].value_counts().head(15).plot(kind = 'bar')
plt.xlabel('LOT')
plt.ylabel('count')
plt.savefig('3.png',bbox_inches='tight')
plt.show()

# %%
mydata['OWNER'].count() * 100 / numrecords
# Out:
# 97.03593110699033

# %%
len(mydata['OWNER'].unique())
# Out:
# 863347

# %%
mydata['OWNER'].value_counts()
# Out:
# PARKCHESTER PRESERVAT    6020
# PARKS AND RECREATION     4255
# DCAS                     2169
# HOUSING PRESERVATION     1904
# CITY OF NEW YORK         1450
#                          ...
# MARIO KARLOVIC              1
# HUSSAIN, SHEIKH D           1
# MUKHANOVA, LYUDMYLA         1
# DIPIERRO DANIEL J           1
# NAWAZ, RAB                  1
# Name: OWNER, Length: 863346, dtype: int64

# %%
mydata['OWNER'].value_counts().head(15).plot(kind='bar')

# %%
plt.rcParams["figure.figsize"] = [15,8]
mydata['OWNER'].value_counts().head(15).plot(kind = 'bar')
plt.xlabel('OWNER')
plt.ylabel('count')
plt.savefig('4.png',bbox_inches='tight')
plt.show()

# %%
plt.rcParams["figure.figsize"] = [15,8]
mydata['BLDGCL'].value_counts().head(15).plot(kind = 'bar')

plt.xlabel('BLDGCL')
plt.ylabel('count')
plt.savefig('5.png',bbox_inches='tight')
plt.show()

# %%
plt.rcParams["figure.figsize"] = [15,8]
sns.set(font_scale=2)
plot = sns.countplot(x='TAXCLASS', data = mydata, order = mydata['TAXCLASS'].value_counts().index)
plot.set_yscale('log')
plt.savefig('6.png')

# %%
plt.rcParams["figure.figsize"] = [15,8]
mydata['EXT'].value_counts().plot(kind = 'bar')
plt.xlabel('EXT')
plt.ylabel('count')
plt.savefig('7.png',bbox_inches='tight')
plt.show()

# %%
xhigh = 50
temp = mydata[mydata['STORIES'] > 0]
temp.count()
plt.xlim(0,xhigh)
temp = temp[temp['STORIES'] <= xhigh]
sns.distplot(temp['STORIES'],bins=51, kde=True)
plt.xlabel('STORIES')
plt.ylabel('probability density')
plt.savefig('8.png',bbox_inches='tight')
plt.show()

# %%
plt.rcParams["figure.figsize"] = [15,8]
xhigh = 2000000
plt.xlim(0,xhigh)
temp = mydata[mydata['FULLVAL'] <= xhigh]
sns.distplot(temp['FULLVAL'],bins=100, kde=True)
plt.xlabel('FULLVAL')
plt.ylabel('probability density')
plt.savefig('9.png')

# %%
plt.rcParams["figure.figsize"] = [15,8]
mydata['STADDR'].value_counts().head(15).plot(kind = 'bar')
plt.xlabel('STADDR')
plt.ylabel('count')
plt.savefig('10.png',bbox_inches='tight')
plt.show()

# %%
plt.rcParams["figure.figsize"] = [15,8]
mydata['ZIP'].value_counts().head(15).plot(kind = 'bar')
plt.xlabel('ZIP')
plt.ylabel('count')
plt.savefig('11.png',bbox_inches='tight')
plt.show()

# %%
plt.rcParams["figure.figsize"] = [15,8]
sns.set(font_scale=2)
plot = sns.countplot(x='EXMPTCL', data = mydata, order = mydata['EXMPTCL'].value_counts().index)
plot.set_yscale('log')

plt.savefig('12.png',bbox_inches='tight')
plt.show()

# %%
xhigh = 50000
plt.xlim(0,xhigh)
temp = mydata[mydata['AVLAND'] <= xhigh]
sns.distplot(temp['AVLAND'],bins=100, kde=True)
plt.xlabel('AVLAND')
plt.ylabel('probability density')
plt.savefig('13.png',bbox_inches='tight')
plt.show()

# %%
xhigh = 100000
plt.xlim(0,xhigh)
temp = mydata[mydata['AVTOT'] <= xhigh]
sns.distplot(temp['AVTOT'],bins=100, kde=True)
plt.xlabel('AVTOT')
plt.ylabel('probability density')
plt.savefig('14.png',bbox_inches='tight')
plt.show()

# %%
xhigh = 10000
plt.xlim(0,xhigh)

plt.xlabel('EXLAND')
plt.ylabel('probability density')
temp = mydata[mydata['EXLAND'] <= xhigh]
sns.distplot(temp['EXLAND'],bins=100, kde=True)
plt.savefig('15.png',bbox_inches='tight')
plt.show()

# %%
xhigh = 10000
plt.xlim(0,xhigh)
temp = mydata[mydata['EXTOT'] <= xhigh]
temp.count()
sns.distplot(temp['EXTOT'],bins= 100, kde=True)

plt.xlabel('EXTOT')
plt.ylabel('probability density')
plt.savefig('16.png',bbox_inches='tight')

# %%
xhigh = 8000
plt.xlim(0,xhigh)
temp = mydata[mydata['EXCD1'] <= xhigh]
sns.distplot(temp['EXCD1'],bins=100, kde=True)

plt.xlabel('EXCD1')
plt.ylabel('probability density')
plt.savefig('17.png',bbox_inches='tight')

# %%
xhigh = 250
plt.xlim(0,xhigh)
temp = mydata[mydata['LTFRONT'] <= xhigh]
sns.distplot(temp['LTFRONT'],bins=100, kde=True)

plt.xlabel('LTFRONT')
plt.ylabel('probability density')
plt.savefig('18.png',bbox_inches='tight')

# %%
xhigh = 250
plt.xlim(0,xhigh)
temp = mydata[mydata['LTDEPTH'] <= xhigh]
sns.distplot(temp['LTDEPTH'],bins=100, kde=True)
plt.xlabel('LTDEPTH')
plt.ylabel('probability density')
plt.savefig('19.png',bbox_inches='tight')

# %%
xhigh = 250
plt.xlim(0,xhigh)
temp = mydata[mydata['BLDFRONT'] <= xhigh]
sns.distplot(temp['BLDFRONT'],bins=100, kde=True)
plt.xlabel('BLDFRONT')
plt.ylabel('probability density')
plt.savefig('20.png',bbox_inches='tight')

# %%
xhigh = 300
plt.xlim(0,xhigh)
temp = mydata[mydata['BLDDEPTH'] <= xhigh]
sns.distplot(temp['BLDDEPTH'],bins=100, kde=True)
plt.xlabel('BLDDEPTH')
plt.ylabel('probability density')
plt.savefig('21.png',bbox_inches='tight')

# %%
xhigh = 300000
plt.xlim(0,xhigh)
temp = mydata[mydata['AVLAND2'] <= xhigh]
sns.distplot(temp['AVLAND2'],bins=100, kde=True)
plt.xlabel('AVLAND2')
plt.ylabel('probability density')
plt.savefig('22.png',bbox_inches='tight')

# %%
xhigh = 1000000
plt.xlim(0,xhigh)
temp = mydata[mydata['AVTOT2'] <= xhigh]
sns.distplot(temp['AVTOT2'],bins=100, kde=True)
plt.xlabel('AVTOT2')
plt.ylabel('probability density')
plt.savefig('23.png',bbox_inches='tight')

# %%
xhigh = 20000
plt.xlim(0,xhigh)
temp = mydata[mydata['EXLAND2'] <= xhigh]
sns.distplot(temp['EXLAND2'],bins=100, kde=True)
plt.xlabel('EXLAND2')
plt.ylabel('probability density')
plt.savefig('24.png',bbox_inches='tight')

# %%
xhigh =150000
plt.xlim(0,xhigh)
temp = mydata[mydata['EXTOT2'] <= xhigh]
sns.distplot(temp['EXTOT2'],bins=100, kde=True)
plt.xlabel('EXTOT2')
plt.ylabel('probability density')
plt.savefig('25.png',bbox_inches='tight')

# %%
xhigh = 8000
plt.xlim(0,xhigh)
temp = mydata[mydata['EXCD2'] <= xhigh]
sns.distplot(temp['EXCD2'],bins=100, kde=True)
plt.xlabel('EXCD2')
plt.ylabel('probability density')
plt.savefig('26.png',bbox_inches='tight')

# %%
mydata['BLDGCL'].count() * 100 / numrecords
# Out:
# 100.0

# %%
len(mydata['BLDGCL'].unique())
# Out:
# 200

# %%
mydata['BLDGCL'].value_counts()
# Out:
# R4    139879
# A1    123369
# A5     96984
# B1     84208
# B2     77598
# C0     73111
# B3     59240
# A2     51130
# A9     26177
# B9     26133
# V0     24049
# R5     23957
# R3     21667
# C3     16343
# C1     15070
# S2     14507
# C2     13633
# R2     10558
# R1      8015
# K1      7596
# C7      7546
# V1      7223
# A0      6889
# A3      6332
# S1      6195
# R0      5696
# G7      5603
# D1      5101
# S9      4125
# K9      4080
#        ...
# H1        28
# Y8        28
# Y4        28
# F8        26
# U0        25
# Y7        25
# J5        20
# C8        18
# J8        18
# V4        17
# U5        17
# Q5        17
# N1        16
# Y3        16
# T1        15
# V6        14
# P4        14
# P1        13
# J1        12
# N3        11
# J3         8
# J7         8
# J2         7
# N4         7
# Z5         6
# I2         4
# I3         4
# H7         3
# E6         1
# Y5         1
# Name: BLDGCL, Length: 200, dtype: int64

# %%
mydata[mydata['BLDGCL'] == 0]
# Out:
# Empty DataFrame
# Columns: [RECORD, BBLE, B, BLOCK, LOT, EASEMENT, OWNER, BLDGCL, TAXCLASS, LTFRONT, LTDEPTH, EXT, STORIES, FULLVAL, AVLAND, AVTOT, EXLAND, EXTOT, EXCD1, STADDR, ZIP, EXMPTCL, BLDFRONT, BLDDEPTH, AVLAND2, AVTOT2, EXLAND2, EXTOT2, EXCD2, PERIOD, YEAR, VALTYPE]
# Index: []
#
# [0 rows x 32 columns]

# %%
mydata['TAXCLASS'].count() * 100 / numrecords
# Out:
# 100.0

# %%
len(mydata['TAXCLASS'].unique())
# Out:
# 11

# %%
mydata['TAXCLASS'].value_counts()
# Out:
# 1     660721
# 2     188612
# 4     104310
# 2A     40574
# 1B     24738
# 1A     21667
# 2B     13964
# 2C     10795
# 3       4638
# 1C       946
# 1D        29
# Name: TAXCLASS, dtype: int64

# %%
mydata['LTFRONT'].count() * 100 / numrecords
# Out:
# 100.0

# %%
sns.distplot(mydata['LTFRONT'])

# %%
sns.boxplot(x='LTFRONT', data=mydata)

# %%
sns.distplot(mydata['LTFRONT'])

# %%
xhigh = 300
plt.xlim(0,xhigh)
temp = mydata[mydata['LTFRONT'] <= xhigh]
sns.distplot(temp['LTFRONT'],bins=100, kde=True)

# %%
len(mydata[mydata['LTFRONT']==0])
# Out:
# 169108

# %%
len(mydata[mydata['LTFRONT']==1])
# Out:
# 839

# %%
len(mydata[mydata["LTFRONT"]==2])
# Out:
# 762

# %%
mydata['LTFRONT'].value_counts()
# Out:
# 0       169108
# 20      135178
# 25      117306
# 40       85389
# 18       40668
# 50       39897
# 30       36340
# 24       25710
# 19       25381
# 22       23420
# 26       19721
# 21       19376
# 16       18636
# 23       16937
# 60       14972
# 100      13952
# 28       13230
# 27       12648
# 17       10522
# 29        9366
# 37        8158
# 33        8126
# 35        7868
# 32        7619
# 31        7388
# 45        7032
# 75        6862
# 41        6240
# 42        5965
# 15        5283
#          ...
# 782          1
# 5400         1
# 2290         1
# 781          1
# 1269         1
# 1270         1
# 2294         1
# 5370         1
# 1276         1
# 2300         1
# 1282         1
# 1283         1
# 1802         1
# 2309         1
# 1284         1
# 1285         1
# 5380         1
# 1287         1
# 1290         1
# 776          1
# 1295         1
# 1297         1
# 775          1
# 1299         1
# 1300         1
# 1301         1
# 1302         1
# 774          1
# 2331         1
# 1023         1
# Name: LTFRONT, Length: 1297, dtype: int64

# %%
mydata['LTDEPTH'].count() * 100 / numrecords
# Out:
# 100.0

# %%
sns.boxplot(x='LTDEPTH', data=mydata)

# %%
sns.distplot(mydata['LTDEPTH'],kde=False)

# %%
xhigh = 300
plt.xlim(0,xhigh)
temp = mydata[mydata['LTDEPTH'] <= xhigh]
sns.distplot(temp['LTDEPTH'],bins=100, kde=True)

# %%
len(mydata[mydata['LTDEPTH']==0])
# Out:
# 170128

# %%
len(mydata[mydata['LTDEPTH']==1])
# Out:
# 127

# %%
len(mydata[mydata["LTDEPTH"]==2])
# Out:
# 84

# %%
mydata['LTDEPTH'].value_counts()
# Out:
# 100     464541
# 0       170128
# 95       31612
# 90       20294
# 80       16671
# 99       11390
# 97       10227
# 75       10161
# 102       9607
# 96        9329
# 110       8943
# 98        8757
# 105       8522
# 101       7697
# 120       7683
# 85        7328
# 125       7324
# 103       6995
# 92        6734
# 200       6692
# 94        5971
# 93        4964
# 107       4810
# 109       4528
# 60        4522
# 50        4505
# 87        4449
# 104       4414
# 150       4393
# 114       4246
#          ...
# 1251         1
# 1825         1
# 1231         1
# 2866         1
# 838          1
# 819          1
# 1860         1
# 4934         1
# 2231         1
# 2885         1
# 8000         1
# 835          1
# 1209         1
# 832          1
# 5948         1
# 1477         1
# 1853         1
# 1215         1
# 3900         1
# 1476         1
# 1218         1
# 827          1
# 2875         1
# 1472         1
# 1222         1
# 1471         1
# 1224         1
# 820          1
# 2253         1
# 4720         1
# Name: LTDEPTH, Length: 1370, dtype: int64

# %%
mydata['EXT'].value_counts()
# Out:
# G     266970
# E      49442
# EG     37893
# Name: EXT, dtype: int64

# %%
mydata['EXT'].count() * 100 / numrecords
# Out:
# 33.081884679092504

# %%
mydata['STORIES'].count() * 100 / numrecords
# Out:
# 94.74656253909919

# %%
sum(pd.isnull(mydata['STORIES']))
# Out:
# 56264

# %%
sns.boxplot(x='STORIES', data=mydata)
plt.savefig("boxplot.png")

# %%
len(mydata[mydata['STORIES'] == 0])
# Out:
# 0

# %%
sns.boxplot(x='STORIES', data=mydata)

# %%
xhigh = 50
temp = mydata[mydata['STORIES'] > 0]
temp.count()
plt.xlim(0,xhigh)
temp = temp[temp['STORIES'] <= xhigh]
sns.distplot(temp['STORIES'],bins=51, kde=True)

# %%
len(mydata[mydata['STORIES'] == 1])
# Out:
# 96706

# %%
mydata['STORIES'].value_counts()
# Out:
# 2.0      415092
# 3.0      130127
# 1.0       96706
# 2.5       82292
# 4.0       38342
# 6.0       30936
# 5.0       25971
# 1.5       24770
# 2.7       13595
# 12.0      12198
# 8.0       11953
# 7.0       11899
# 1.6        8954
# 9.0        7343
# 13.0       7330
# 16.0       5428
# 1.7        5239
# 21.0       4885
# 19.0       4866
# 11.0       4459
# 15.0       4270
# 10.0       3758
# 17.0       3457
# 14.0       3368
# 20.0       3142
# 32.0       3127
# 30.0       2905
# 42.0       2875
# 31.0       2583
# 27.0       2333
#           ...
# 6.7          12
# 59.0         12
# 3.6          11
# 47.0         10
# 4.7          10
# 1.9          10
# 74.0          6
# 3.3           5
# 100.0         5
# 9.5           4
# 62.0          3
# 2.8           3
# 1.1           3
# 1.3           3
# 8.5           3
# 68.0          2
# 2.9           2
# 5.7           2
# 1.4           2
# 63.0          2
# 2.4           2
# 119.0         1
# 82.0          1
# 4.2           1
# 114.0         1
# 76.0          1
# 2.1           1
# 61.0          1
# 85.0          1
# 78.0          1
# Name: STORIES, Length: 111, dtype: int64

# %%
mydata['FULLVAL'].count() * 100 / numrecords
# Out:
# 100.0

# %%
sns.boxplot(x='FULLVAL', data=mydata)
plt.savefig("boxplot.png")

# %%
sns.distplot(mydata['FULLVAL'],kde=False)
plt.savefig('dist bad.png')

# %%
len(mydata[mydata['FULLVAL']==0])
# Out:
# 13007

# %%
len(mydata[mydata['FULLVAL']==1])
# Out:
# 0

# %%
len(mydata[mydata["FULLVAL"]==2])
# Out:
# 0

# %%
temp = mydata[mydata['FULLVAL'] >= 0]
ax = sns.distplot(temp['FULLVAL'],bins=100, kde=False)
ax.set_yscale('log')
plt.savefig('log.png')

# %%
temp = mydata[mydata['FULLVAL'] >= 0]
ax = sns.distplot(temp['FULLVAL'],bins=100, kde=False)
ax.set_yscale('log')
ax.set_xscale('log')
plt.savefig('loglog.png')

# %%
xhigh = 2000000
plt.xlim(0,xhigh)
temp = mydata[mydata['FULLVAL'] <= xhigh]
sns.distplot(temp['FULLVAL'],bins=100, kde=False)
plt.savefig('dist good.png')

# %%
xhigh = 2000000
plt.xlim(0,xhigh)
temp = mydata[mydata['FULLVAL'] <= xhigh]
sns.distplot(temp['FULLVAL'],bins=10, kde=False)
plt.savefig('dist good.png')

# %%
xhigh = 2000000
plt.xlim(0,xhigh)
temp = mydata[mydata['FULLVAL'] <= xhigh]
sns.distplot(temp['FULLVAL'],bins=1000, kde=False)
plt.savefig('dist good.png')

# %%
xhigh = 1000000
plt.xlim(0,xhigh)
temp = mydata[mydata['FULLVAL'] <= xhigh]
sns.distplot(temp['FULLVAL'],bins=100, kde=True)

# %%
xhigh = 100000
plt.xlim(0,xhigh)
temp = mydata[(mydata['FULLVAL'] <= xhigh) & (mydata['FULLVAL']) > 0]
sns.distplot(temp['FULLVAL'],bins=100, kde=False)

# %%
len(mydata[mydata['FULLVAL'] == 0])
# Out:
# 13007

# %%
mydata['AVLAND'].count() * 100 / numrecords
# Out:
# 100.0

# %%
sns.boxplot(x='AVLAND', data=mydata)

# %%
sns.distplot(mydata['AVLAND'],kde=False)

# %%
len(mydata[mydata['AVLAND']==0])
# Out:
# 13009

# %%
len(mydata[mydata['AVLAND']==1])
# Out:
# 3

# %%
len(mydata[mydata["AVLAND"]==2])
# Out:
# 13

# %%
xhigh = 50000
plt.xlim(0,xhigh)
temp = mydata[mydata['AVLAND'] <= xhigh]
sns.distplot(temp['AVLAND'],bins=100, kde=True)

# %%
mydata['AVTOT'].count() * 100 / numrecords
# Out:
# 100.0

# %%
sns.boxplot(x='AVTOT', data=mydata)

# %%
xhigh = 100000
plt.xlim(0,xhigh)
temp = mydata[mydata['AVTOT'] <= xhigh]
sns.distplot(temp['AVTOT'],bins=100, kde=True)

# %%
len(mydata[mydata['AVTOT']==0])
# Out:
# 13007

# %%
len(mydata[mydata['AVTOT']==1])
# Out:
# 3

# %%
len(mydata[mydata["AVTOT"]==2])
# Out:
# 2

# %%
mydata['EXLAND'].count() * 100 / numrecords
# Out:
# 100.0

# %%
sns.boxplot(x='EXLAND', data=mydata)

# %%
xhigh = 20000
plt.xlim(0,xhigh)
temp = mydata[mydata['EXLAND'] <= xhigh]
sns.distplot(temp['EXLAND'],bins=100, kde=False)

# %%
len(mydata[mydata['EXLAND']==0])
# Out:
# 491699

# %%
len(mydata[mydata['EXLAND']==1])
# Out:
# 8

# %%
len(mydata[mydata["EXLAND"]==2])
# Out:
# 15

# %%
mydata['EXTOT'].count() * 100 / numrecords
# Out:
# 100.0

# %%
sns.boxplot(x='EXTOT', data=mydata)

# %%
xhigh = 10000
plt.xlim(0,xhigh)
temp = mydata[mydata['EXTOT'] <= xhigh]
sns.distplot(temp['EXTOT'],bins=100, kde=False)

# %%
len(mydata[mydata['EXTOT']==0])
# Out:
# 432572

# %%
len(mydata[mydata['EXTOT']==1])
# Out:
# 10

# %%
len(mydata[mydata["EXTOT"]==2])
# Out:
# 2

# %%
mydata['EXCD1'].count() * 100 / numrecords
# Out:
# 59.616393742635346

# %%
sns.boxplot(x='EXCD1', data=mydata)

# %%
xhigh = 10000
plt.xlim(0,xhigh)
temp = mydata[mydata['EXCD1'] <= xhigh]
sns.distplot(temp['EXCD1'],bins=100, kde=False)

# %%
len(mydata[mydata['EXCD1']==0])
# Out:
# 0

# %%
len(mydata[mydata['EXCD1']==1])
# Out:
# 0

# %%
len(mydata[mydata["EXCD1"]==2])
# Out:
# 0

# %%
mydata['STADDR'].count() * 100 / numrecords
# Out:
# 99.93688106562689

# %%
len(mydata['STADDR'].unique())
# Out:
# 839281

# %%
mydata['STADDR'].value_counts()
# Out:
# 501 SURF AVENUE               902
# 330 EAST 38 STREET            817
# 322 WEST 57 STREET            720
# 155 WEST 68 STREET            671
# 20 WEST 64 STREET             657
# 1 IRVING PLACE                650
# 220 RIVERSIDE BOULEVARD       628
# 360 FURMAN STREET             599
# 200 EAST 66 STREET            585
# 30 WEST 63 STREET             562
# 2 BAY CLUB DRIVE              556
# 350 WEST 42 STREET            556
# 200 RECTOR PLACE              549
# 301 EAST 79 STREET            538
# 350 WEST 50 STREET            498
# 630 1 AVENUE                  488
# 635 WEST 42 STREET            483
# 88 GREENWICH STREET           453
# 150 WEST 51 STREET            447
# 99 JOHN STREET                445
# 25 CENTRAL PARK WEST          441
# 138-35 ELDER AVENUE           437
# 1623 3 AVENUE                 434
# 1 BAY CLUB DRIVE              427
# 5 EAST 22 STREET              426
# 310 WEST 52 STREET            425
# 106 CENTRAL PARK SOUTH        420
# 382 CENTRAL PARK WEST         415
# 400 CENTRAL PARK WEST         415
# 25-40 SHORE BOULEVARD         415
#                              ...
# 149 STARR STREET                1
# 85-01 HOMELAWN STREET           1
# 5702 4 AVENUE                   1
# 1421 WEBSTER AVENUE             1
# 3799 EAST TREMONT AVENUE        1
# 89 ORMSBY AVENUE                1
# 58-42 206 STREET                1
# 150-25 FOCH BOULEVARD           1
# 4 BRIGHTON COURT                1
# 612 ARLENE STREET               1
# 44 MANILA PLACE                 1
# 1924 HONE AVENUE                1
# 187-28 JORDAN AVENUE            1
# 2367 EAST 29 STREET             1
# 991 HART STREET                 1
# 90-06 95 AVENUE                 1
# 120 WEST 75 STREET              1
# 19 GUILFORD STREET              1
# 910 CARLTON BOULEVARD           1
# 415 MONTAUK AVENUE              1
# 106 SERRELL AVENUE              1
# 1420 PROSPECT AVENUE            1
# 816 47 STREET                   1
# 64-17 CLINTON AVENUE            1
# 25-17 166 STREET                1
# 133-11 AMBER STREET             1
# 402 LINWOOD STREET              1
# 555 74 STREET                   1
# 56-20 CLOVERDALE BOULEVARD      1
# 4156 BRONXWOOD AVENUE           1
# Name: STADDR, Length: 839280, dtype: int64

# %%
mydata['ZIP'].count() * 100 / numrecords
# Out:
# 97.20913469169761

# %%
len(mydata['ZIP'].unique())
# Out:
# 197

# %%
mydata['ZIP'].value_counts()
# Out:
# 10314.0    24606
# 11234.0    20001
# 10312.0    18127
# 10462.0    16905
# 10306.0    16578
# 11236.0    15678
# 11385.0    14921
# 11229.0    12793
# 11211.0    12710
# 11207.0    12293
# 11215.0    11834
# 11235.0    11312
# 11203.0    11241
# 11208.0    11139
# 11204.0    11061
# 10469.0    11030
# 11214.0    10886
# 11223.0    10741
# 10305.0    10625
# 11434.0    10505
# 11355.0    10492
# 11219.0    10300
# 11357.0     9851
# 11413.0     9784
# 11373.0     9779
# 11220.0     9686
# 10023.0     9518
# 10309.0     9416
# 10016.0     9362
# 10019.0     9355
#            ...
# 10004.0      775
# 10006.0      721
# 10475.0      687
# 10034.0      650
# 10039.0      596
# 10044.0      588
# 10040.0      546
# 10037.0      526
# 11040.0      450
# 11239.0      195
# 11109.0      194
# 11243.0      185
# 10020.0      120
# 10803.0       46
# 10282.0       22
# 11430.0       14
# 11697.0       10
# 11227.0        5
# 33803.0        3
# 10281.0        3
# 11696.0        2
# 11242.0        2
# 11695.0        2
# 10048.0        2
# 11352.0        1
# 11005.0        1
# 11241.0        1
# 11371.0        1
# 11359.0        1
# 10162.0        1
# Name: ZIP, Length: 196, dtype: int64

# %%
mydata['EXMPTCL'].count() * 100 / numrecords
# Out:
# 1.4546299979271593

# %%
len(mydata['EXMPTCL'].unique())
# Out:
# 15

# %%
mydata['EXMPTCL'].value_counts()
# Out:
# X1    6912
# X5    5208
# X7     820
# X2     770
# X6     764
# X4     441
# X8     292
# X3     259
# X9     108
# R4       1
# 5        1
# KI       1
# VI       1
# A9       1
# Name: EXMPTCL, dtype: int64

# %%
sns.boxplot(x='BLDFRONT', data=mydata)

# %%
xhigh = 200
plt.xlim(0,xhigh)
temp = mydata[mydata['BLDFRONT'] <= xhigh]
sns.distplot(temp['BLDFRONT'],bins=100, kde=False)

# %%
len(mydata[mydata['BLDFRONT']==0])
# Out:
# 228815

# %%
len(mydata[mydata['BLDFRONT']==1])
# Out:
# 77

# %%
len(mydata[mydata["BLDFRONT"]==2])
# Out:
# 21

# %%
mydata['BLDDEPTH'].count() * 100 / numrecords
# Out:
# 100.0

# %%
sns.boxplot(x='BLDDEPTH', data=mydata)

# %%
xhigh = 300
plt.xlim(0,xhigh)
temp = mydata[mydata['BLDDEPTH'] <= xhigh]
sns.distplot(temp['BLDDEPTH'],bins=100, kde=False)

# %%
len(mydata[mydata['BLDDEPTH']==0])
# Out:
# 228853

# %%
len(mydata[mydata['BLDDEPTH']==1])
# Out:
# 59

# %%
len(mydata[mydata["BLDDEPTH"]==2])
# Out:
# 10

# %%
mydata['AVLAND2'].count() * 100 / numrecords
# Out:
# 26.398467218303743

# %%
mydata['AVLAND2'].count() * 100/ numrecords
# Out:
# 26.398467218303743

# %%
sns.boxplot(x='AVLAND2', data=mydata)

# %%
xhigh = 300000
plt.xlim(0,xhigh)
temp = mydata[mydata['AVLAND2'] <= xhigh]
sns.distplot(temp['AVLAND2'],bins=100, kde=False)

# %%
mydata['AVTOT2'].count() * 100 / numrecords
# Out:
# 26.399027445531907

# %%
sns.boxplot(x='AVTOT2', data=mydata)

# %%
xhigh = 1000000
plt.xlim(0,xhigh)
temp = mydata[mydata['AVTOT2'] <= xhigh]
sns.distplot(temp['AVTOT2'],bins=100, kde=False)

# %%
mydata['EXLAND2'].count() * 100 / numrecords
# Out:
# 8.165218479281863

# %%
sns.boxplot(x='EXLAND2', data =mydata)

# %%
xhigh = 50000
plt.xlim(0,xhigh)
temp = mydata[mydata['EXLAND2'] <= xhigh]
sns.distplot(temp['EXLAND2'],bins=100, kde=False)

# %%
mydata['EXTOT2'].count() * 100 / numrecords
# Out:
# 12.215567967701032

# %%
sns.boxplot(x='EXTOT2', data=mydata)

# %%
xhigh = 300000
plt.xlim(0,xhigh)
temp = mydata[mydata['EXTOT2'] <= xhigh]
sns.distplot(temp['EXTOT2'],bins=100, kde=False)

# %%
mydata['EXCD2'].count() * 100 / numrecords
# Out:
# 8.678666733893934

# %%
sns.boxplot(x='EXCD2', data=mydata)

# %%
xhigh = 10000
plt.xlim(0,xhigh)
temp = mydata[mydata['EXCD2'] <= xhigh]
sns.distplot(temp['EXCD2'],bins=100, kde=False)

# %%
mydata['PERIOD'].count() * 100 / numrecords
# Out:
# 100.0

# %%
len(mydata['PERIOD'].unique())
# Out:
# 1

# %%
mydata['PERIOD'].value_counts()
# Out:
# FINAL    1070994
# Name: PERIOD, dtype: int64

# %%
mydata['YEAR'].count() * 100 / numrecords
# Out:
# 100.0

# %%
len(mydata['YEAR'].unique())
# Out:
# 1

# %%
mydata['YEAR'].value_counts()
# Out:
# 2010/11    1070994
# Name: YEAR, dtype: int64

# %%
mydata['VALTYPE'].count() * 100 / numrecords
# Out:
# 100.0

# %%
len(mydata['VALTYPE'].unique())
# Out:
# 1

# %%
mydata['VALTYPE'].value_counts()
# Out:
# AC-TR    1070994
# Name: VALTYPE, dtype: int64

# %%
len(mydata[mydata['LTFRONT'] == 0])
# Out:
# 169108

# %%
len(mydata[mydata['LTDEPTH'] == 0])
# Out:
# 170128

# %%
len(mydata[(mydata['LTFRONT'] == 0) & (mydata['LTFRONT'] == 0)])
# Out:
# 169108

# %%
temp = mydata[(mydata['LTFRONT'] == 0) & (mydata['LTFRONT'] == 0)]

# %%
temp['BLDFRONT'].value_counts()
# Out:
# 0      150872
# 20        835
# 100       821
# 200       696
# 25        655
# 18        620
# 160       585
# 116       561
# 24        560
# 175       453
# 190       444
# 128       444
# 22        439
# 151       437
# 97        435
# 115       415
# 261       400
# 132       386
# 201       372
# 134       358
# 21        354
# 75        339
# 23        305
# 78        286
# 110       272
# 70        271
# 19        265
# 146       253
# 202       230
# 50        226
#         ...
# 264         2
# 13          2
# 206         2
# 180         2
# 182         2
# 214         2
# 532         2
# 220         2
# 870         1
# 982         1
# 158         1
# 81          1
# 179         1
# 900         1
# 133         1
# 243         1
# 6           1
# 111         1
# 48          1
# 421         1
# 199         1
# 265         1
# 94          1
# 222         1
# 195         1
# 140         1
# 155         1
# 95          1
# 106         1
# 780         1
# Name: BLDFRONT, Length: 154, dtype: int64

# %%
temp['BLDDEPTH'].value_counts()
# Out:
# 0       150858
# 100       1262
# 97         733
# 596        584
# 106        563
# 24         538
# 125        491
# 146        453
# 172        445
# 179        413
# 149        412
# 185        400
# 48         385
# 60         381
# 99         361
# 115        358
# 298        347
# 65         333
# 64         320
# 221        315
# 98         282
# 50         277
# 135        274
# 102        269
# 198        251
# 43         251
# 42         234
# 327        229
# 40         212
# 70         206
#          ...
# 390          1
# 21           1
# 530          1
# 525          1
# 126          1
# 507          1
# 147          1
# 109          1
# 375          1
# 405          1
# 208          1
# 320          1
# 3390         1
# 1980         1
# 439          1
# 182          1
# 225          1
# 171          1
# 228          1
# 103          1
# 492          1
# 493          1
# 292          1
# 622          1
# 544          1
# 160          1
# 413          1
# 409          1
# 535          1
# 511          1
# Name: BLDDEPTH, Length: 169, dtype: int64

# %%
mydata['EASEMENT'].value_counts().head(20).plot(kind='bar',logy=True)

# %%
print('duration: ', pd.datetime.now() - start_time)
# Out:
# duration:  0:01:47.711317
